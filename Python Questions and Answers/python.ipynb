# %% [markdown]
# * *  Python Questions

# %% [markdown]
# There are questions that we cover for the prepration of python . 100 questins are general questiaons or theory questions and 100 questions are practical based questions!

# %% [markdown]
# * 1. Python Fundamentals
#
# What is Python, and what are its key features?
#
# How do you install Python on your system?
#
# What are Python’s data types?
#
# What is the difference between int and float?
#
# How do you check the data type of a variable?
#
# What are Python keywords, and can you name a few?
#
# What is the difference between == and is in Python?
#
# How do you write comments in Python?
#
# What is the purpose of the pass statement?
#
# What is the difference between print() and return?

# %% [markdown]
# * 2. Variables and Operators
#
# How do you declare a variable in Python?
#
# What is the difference between = and ==?
#
# What are the arithmetic operators in Python?
#
# What is the difference between / and //?
#
# What is the purpose of the ** operator?
#
# What are comparison operators in Python?
#
# What are logical operators in Python?
#
# What is the purpose of the in operator?
#
# What is the difference between and, or, and not?
#
# What is the purpose of the += operator?

# %% [markdown]
# * 3. Strings
#
# How do you create a string in Python?
#
# What is string slicing, and how does it work?
#
# How do you concatenate two strings?
#
# What is the difference between str() and repr()?
#
# How do you find the length of a string?
#
# What is the purpose of the strip() method?
#
# How do you convert a string to lowercase or uppercase?
#
# What is the difference between find() and index()?
#
# How do you replace a substring in a string?
#
# What is string formatting, and how do you use it?

# %% [markdown]
# * 4. Lists
#
# How do you create a list in Python?
#
# What is the difference between append() and extend()?
#
# How do you access elements in a list?
#
# What is list slicing, and how does it work?
#
# How do you remove an element from a list?
#
# What is the difference between remove() and pop()?
#
# How do you sort a list in Python?
#
# What is the purpose of the reverse() method?
#
# How do you check if an element exists in a list?
#
# What is the difference between a list and a tuple?

# %% [markdown]
# * 5. Tuples
#
# How do you create a tuple in Python?
#
# What is the difference between a tuple and a list?
#
# Can you modify a tuple after it is created?
#
# How do you access elements in a tuple?
#
# What is tuple unpacking?
#
# How do you convert a tuple to a list?
#
# What is the purpose of the count() method in tuples?
#
# How do you check if an element exists in a tuple?
#
# What is the difference between tuple() and list()?
#
# Can a tuple contain mutable objects?

# %% [markdown]
# * 6. Dictionaries
#
# How do you create a dictionary in Python?
#
# What is the difference between a dictionary and a list?
#
# How do you access values in a dictionary?
#
# How do you add a new key-value pair to a dictionary?
#
# How do you remove a key-value pair from a dictionary?
#
# What is the purpose of the keys() method?
#
# What is the purpose of the values() method?
#
# How do you check if a key exists in a dictionary?
#
# What is the purpose of the items() method?
#
# How do you merge two dictionaries?

# %% [markdown]
# * 7. Sets
#
# How do you create a set in Python?
#
# What is the difference between a set and a list?
#
# How do you add elements to a set?
#
# How do you remove elements from a set?
#
# What is the purpose of the union() method?
#
# What is the purpose of the intersection() method?
#
# What is the difference between discard() and remove()?
#
# How do you check if an element exists in a set?
#
# What is the purpose of the difference() method?
#
# Can a set contain mutable objects?

# %% [markdown]
# * 8. Control Flow
#
# What is the purpose of the if statement?
#
# What is the difference between if and elif?
#
# How do you write a for loop in Python?
#
# What is the purpose of the range() function?
#
# How do you write a while loop in Python?
#
# What is the purpose of the break statement?
#
# What is the purpose of the continue statement?
#
# How do you use the else clause with loops?
#
# What is the difference between break and continue?
#
# How do you write a nested loop in Python?

# %% [markdown]
# * 9. Functions
#
# How do you define a function in Python?
#
# What is the purpose of the return statement?
#
# What is the difference between return and print?
#
# How do you pass arguments to a function?
#
# What is the difference between positional and keyword arguments?
#
# What is the purpose of the *args parameter?
#
# What is the purpose of the **kwargs parameter?
#
# What is a lambda function, and how do you use it?
#
# What is the difference between a function and a method?
#
# How do you define a recursive function?

# %% [markdown]
# * 10. File Handling
#
# How do you open a file in Python?
#
# What is the difference between read() and readlines()?
#
# How do you write to a file in Python?
#
# What is the purpose of the with statement in file handling?
#
# How do you check if a file exists in Python?
#
# How do you delete a file in Python?
#
# What is the purpose of the seek() method?
#
# How do you read a CSV file in Python?
#
# How do you handle exceptions in file handling?
#
# What is the difference between r, w, and a modes in file handling?

# %% [markdown]
# * * * Section 2: Practical Python Problems (100 Questions)

# %% [markdown]
# * 1. Basic Problems
#
# Write a program to print "Hello, World!".
#
# Write a program to add two numbers.
#
# Write a program to find the largest of three numbers.
#
# Write a program to check if a number is even or odd.
#
# Write a program to find the factorial of a number.
#
# Write a program to check if a number is prime.
#
# Write a program to print the Fibonacci series.
#
# Write a program to reverse a string.
#
# Write a program to check if a string is a palindrome.
#
# Write a program to count the number of vowels in a string.

# %% [markdown]
# * 2. List Problems
#
# Write a program to find the sum of all elements in a list.
#
# Write a program to find the largest element in a list.
#
# Write a program to remove duplicates from a list.
#
# Write a program to sort a list in ascending order.
#
# Write a program to reverse a list.
#
# Write a program to find the second largest element in a list.
#
# Write a program to merge two lists.
#
# Write a program to find the common elements between two lists.
#
# Write a program to remove all occurrences of an element from a list.
#
# Write a program to flatten a nested list.

# %% [markdown]
# * 3. Dictionary Problems
#
# Write a program to add a key-value pair to a dictionary.
#
# Write a program to remove a key-value pair from a dictionary.
#
# Write a program to check if a key exists in a dictionary.
#
# Write a program to merge two dictionaries.
#
# Write a program to find the length of a dictionary.
#
# Write a program to sort a dictionary by key.
#
# Write a program to sort a dictionary by value.
#
# Write a program to find the maximum value in a dictionary.
#
# Write a program to find the minimum value in a dictionary.
#
# Write a program to count the frequency of elements in a list using a dictionary.

# %% [markdown]
# * 4. Set Problems
#
# Write a program to find the union of two sets.
#
# Write a program to find the intersection of two sets.
#
# Write a program to find the difference between two sets.
#
# Write a program to check if a set is a subset of another set.
#
# Write a program to remove an element from a set.
#
# Write a program to add multiple elements to a set.
#
# Write a program to find the symmetric difference between two sets.
#
# Write a program to check if two sets are disjoint.
#
# Write a program to convert a list to a set.
#
# Write a program to convert a set to a list.

# %% [markdown]
# * 5. String Problems
#
# Write a program to count the number of words in a string.
#
# Write a program to capitalize the first letter of each word in a string.
#
# Write a program to check if a string contains only digits.
#
# Write a program to check if a string contains only alphabets.
#
# Write a program to replace a word in a string.
#
# Write a program to split a string into a list of words.
#
# Write a program to join a list of words into a string.
#
# Write a program to find the longest word in a string.
#
# Write a program to find the shortest word in a string.
#
# Write a program to count the occurrences of a word in a string.

# %% [markdown]
# * 6. File Handling Problems
#
# Write a program to read a file and print its contents.
#
# Write a program to write to a file.
#
# Write a program to append to a file.
#
# Write a program to count the number of lines in a file.
#
# Write a program to count the number of words in a file.
#
# Write a program to count the number of characters in a file.
#
# Write a program to find the longest word in a file.
#
# Write a program to find the shortest word in a file.
#
# Write a program to copy the contents of one file to another.
#
# Write a program to delete a file.

# %% [markdown]
# * 7. Function Problems
#
# Write a function to find the square of a number.
#
# Write a function to find the cube of a number.
#
# Write a function to check if a number is even.
#
# Write a function to check if a number is odd.
#
# Write a function to find the factorial of a number.
#
# Write a function to find the GCD of two numbers.
#
# Write a function to find the LCM of two numbers.
#
# Write a function to check if a string is a palindrome.
#
# Write a function to reverse a string.
#
# Write a function to count the number of vowels in a string.

# %% [markdown]
# * 8. Advanced Problems
#
# Write a program to implement a stack using a list.
#
# Write a program to implement a queue using a list.
#
# Write a program to implement a linked list.
#
# Write a program to implement a binary search algorithm.
#
# Write a program to implement a bubble sort algorithm.
#
# Write a program to implement a merge sort algorithm.
#
# Write a program to implement a quick sort algorithm.
#
# Write a program to implement a binary search tree.
#
# Write a program to implement a graph.
#
# Write a program to implement a depth-first search (DFS) algorithm.

# %% [markdown]
# * 9. Real-World Problems
#
# Write a program to calculate the area of a circle.
#
# Write a program to calculate the area of a rectangle.
#
# Write a program to calculate the area of a triangle.
#
# Write a program to convert Celsius to Fahrenheit.
#
# Write a program to convert Fahrenheit to Celsius.
#
# Write a program to calculate the compound interest.
#
# Write a program to calculate the simple interest.
#
# Write a program to generate a random password.
#
# Write a program to generate a random number.
#
# Write a program to simulate a dice roll.

# %% [markdown]
# * 10. Miscellaneous Problems
#
# Write a program to find the sum of digits of a number.
#
# Write a program to find the product of digits of a number.
#
# Write a program to reverse a number.
#
# Write a program to check if a number is an Armstrong number.
#
# Write a program to check if a number is a perfect number.
#
# Write a program to find the sum of all prime numbers in a range.
#
# Write a program to find the sum of all even numbers in a range.
#
# Write a program to find the sum of all odd numbers in a range.
#
# Write a program to find the sum of all multiples of 3 or 5 below 1000.
#
# Write a program to generate the first 100 prime numbers.

# %% [markdown]
# * 1. What is Python, and what are its key features?
#
# Answer:
#
# Python is a high-level, interpreted, and general-purpose programming language. It is known for its simplicity and readability, making it a popular choice for beginners and experts alike. Key features of Python include:
#
# Easy to Learn and Use: Python has a simple syntax that resembles English.
#
# Interpreted Language: Python code is executed line by line, making debugging easier.
#
# Dynamically Typed: You don’t need to declare variable types explicitly.
#
# Cross-Platform: Python code can run on Windows, macOS, Linux, etc.
#
# Extensive Libraries: Python has a rich set of libraries for tasks like data analysis, machine learning, web development, etc.
#
# Open Source: Python is free to use and distribute.

# %% [markdown]
# * 2. How do you install Python on your system?
# Answer:
#
# To install Python:
#
# Visit the official Python website: https://www.python.org.
#
# Download the latest version of Python for your operating system (Windows, macOS, or Linux).
#
# Run the installer and follow the instructions.
#
# During installation, ensure you check the box that says "Add Python to PATH" (this makes it easier to run Python from the command line).
#
# Verify the installation by opening a terminal or command prompt and typing:
#
# > python --version

# %% [markdown]
# * 3. What are Python’s data types?
# Answer:
#
# Python has several built-in data types:
#
# Numeric Types: int (integer), float (floating-point number), complex (complex number).
#
# Sequence Types: str (string), list, tuple.
#
# Mapping Type: dict (dictionary).
#
# Set Types: set, frozenset.
#
# Boolean Type: bool (True or False).
#
# Binary Types: bytes, bytearray, memoryview.
# > a = 5          # int
#
# > b = 3.14       # float
#
# > c = "Hello"    # str
#
# > d = [1, 2, 3]  # list
#
# > e = {"key": "value"}  # dict

# %% [markdown]
# * 4. What is the difference between int and float?
#
# Answer:
#
# int: Represents whole numbers (positive or negative) without decimal points. Example: 5, -10.
#
# float: Represents real numbers (positive or negative) with decimal points. Example: 3.14, -0.5.

# %% [markdown]
# * 5. How do you check the data type of a variable?
#
# Answer:
#
# You can use the "type()" function to check the data type of a variable.
#
# > a = 5
#
# > b = 3.14
#
# > c = "Hello"
#
# > print(type(a))  # Output: <class 'int'>
#
# > print(type(b))  # Output: <class 'float'>
#
# > print(type(c))  # Output: <class 'str'>

# %% [markdown]
# * 6. What are Python keywords, and can you name a few?
# Answer:
#
# Python keywords are reserved words that have special meanings and cannot be used as variable names or identifiers. Some common Python keywords include:
#
# if, else, elif (for conditional statements).
#
# for, while (for loops).
#
# def (for defining functions).
#
# class (for defining classes).
#
# import (for importing modules).
#
# return (for returning values from functions).

# %% [markdown]
# * 7. What is the difference between == and is in Python?
# Answer:
#
# ==: Checks if the values of two objects are equal.
#
# is: Checks if two objects refer to the same memory location (i.e., if they are the same object).

# %% [markdown]
# * 8. How do you write comments in Python?
#
# Answer:
#
# Single-line comments: Use the # symbol.
#
# Multi-line comments: Use triple quotes (''' or """), though this is technically a multi-line string and not a comment.

# %% [markdown]
# * 9. What is the purpose of the pass statement?
# Answer:
# The pass statement is a placeholder in Python. It does nothing but is used when a statement is syntactically required but no action is needed.
#
# > if x > 10:
#
#     > pass  # Do nothing for now
#
# > else:
#
#     > print("x is less than or equal to 10")

# %% [markdown]
# * 10. What is the difference between print() and return?
# Answer:
#
# print(): Outputs data to the console. It is used for displaying information to the user.
#
# return: Exits a function and optionally passes a value back to the caller. It is used to return a result from a function.

# %% [markdown]
# * 11. How do you declare a variable in Python?
#
# Answer:
#
# In Python, you declare a variable by assigning a value to it using the = operator. Python is dynamically typed, so you don’t need to specify the variable type explicitly.
#
# > x = 10          # Integer
#
# > y = 3.14        # Float
#
# > name = "Alice"  # String
#
# > is_active = True  # Boolean

# %% [markdown]
# * 12. What is the difference between = and ==?
# Answer:
#
# =: Assignment operator. It is used to assign a value to a variable.
#
# ==: Equality operator. It is used to compare two values for equality.
#
# > x = 5  # Assigns the value 5 to x
#
# > y = 10 # Assigns the value 10 to y
#
# > print(x == y)  # Compares x and y, returns False

# %% [markdown]
# * 13. What are the arithmetic operators in Python?
# Answer:
# Python supports the following arithmetic operators:
#
# + (Addition)
#
# - (Subtraction)
#
# * (Multiplication)
#
# / (Division)
#
# // (Floor Division)
#
# % (Modulus)
#
# ** (Exponentiation)
#
# > a = 10
#
# > b = 3
#
# > print(a + b)   # 13
#
# > print(a - b)   # 7
#
# > print(a * b)   # 30
#
# > print(a / b)   # 3.333...
#
# > print(a // b)  # 3 (Floor division)
#
# > print(a % b)   # 1 (Modulus)
#
# > print(a ** b)  # 1000 (Exponentiation)

# %% [markdown]
# * 14. What is the difference between / and //?
# Answer:
#
# /: Performs normal division and returns a float result.
#
# //: Performs floor division and returns an integer result (rounded down to the nearest whole number).
#
# > print(10 / 3)   # 3.333... (Float division)
#
# > print(10 // 3)  # 3 (Floor division)

# %% [markdown]
# * 15. What is the purpose of the ** operator?
# Answer:
# The ** operator is used for exponentiation (raising a number to the power of another).
#
# > print(2 ** 3)  # 8 (2 raised to the power of 3)
#
# > print(5 ** 2)  # 25 (5 squared)

# %% [markdown]
# * 16. What are comparison operators in Python?
# Answer:
# Comparison operators are used to compare two values. They return a Boolean (True or False). The comparison operators in Python are:
#
# == (Equal to)
#
# != (Not equal to)
#
# > (Greater than)
#
# < (Less than)
#
# >= (Greater than or equal to)
#
# <= (Less than or equal to)
#
# > x = 10
#
# > y = 20
#
# > print(x == y)  # False
#
# > print(x != y)  # True
#
# > print(x > y)   # False
#
# > print(x < y)   # True
#
# > print(x >= y)  # False
#
# > print(x <= y)  # True

# %% [markdown]
# * 17. What are logical operators in Python?
# Answer:
# Logical operators are used to combine conditional statements. The logical operators in Python are:
#
# and: Returns True if both conditions are true.
#
# or: Returns True if at least one condition is true.
#
# not: Reverses the result of a condition.
#
# > x = 5
#
# > y = 10
#
# > print(x > 0 and y > 0)  # True (Both conditions are true)
#
# > print(x > 0 or y < 0)   # True (At least one condition is true)
#
# > print(not x > 0)        # False (Reverses the condition)

# %% [markdown]
# * 18. What is the purpose of the in operator?
# Answer:
# The in operator is used to check if a value exists in a sequence (e.g., list, tuple, string, etc.). It returns True if the value is found, otherwise False.
#
# > fruits = ["apple", "banana", "cherry"]
#
# > print("banana" in fruits)  # True
#
# > print("mango" in fruits)   # False

# %% [markdown]
# * 19. What is the difference between and, or, and not?
# Answer:
#
# and: Returns True if both conditions are true.
#
# or: Returns True if at least one condition is true.
#
# not: Reverses the result of a condition.
#
# > x = 5
#
# > y = 10
#
# > print(x > 0 and y > 0)  # True (Both conditions are true)
#
# > print(x > 0 or y < 0)   # True (At least one condition is true)
#
# > print(not x > 0)        # False (Reverses the condition)

# %% [markdown]
# * 20. What is the purpose of the += operator?
# Answer:
# The += operator is a shorthand for adding a value to a variable and assigning the result back to the variable.
#
# > x = 5
#
# > x += 3  # Equivalent to x = x + 3
#
# > print(x)  # Output: 8
